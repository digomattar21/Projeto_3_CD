# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os.path
import os 
import csv


RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
#Trazendo os dados para o python
data = pd.read_excel('listings.xlsx')
df = data.loc[(data.state=='DC')&(data.city=='Washington')]

# %%
#Selecionando somente as colunas que queremos trabalhar com
colunas = ["latitude", "longitude", "property_type", "accomodations","bathrooms", "bedrooms", "beds", "price", "cleaning_fee", "extra_people","minimum_nights", "review_scores_ra]
df = df.loc
# Out:
#            id                           listing_url       scrape_id  \
# 0     7087327  https://www.airbnb.com/rooms/7087327  20151002231825
# 1      975833   https://www.airbnb.com/rooms/975833  20151002231825
# 3     8409022  https://www.airbnb.com/rooms/8409022  20151002231825
# 5     8634774  https://www.airbnb.com/rooms/8634774  20151002231825
# 6     8498095  https://www.airbnb.com/rooms/8498095  20151002231825
# 23     333613   https://www.airbnb.com/rooms/333613  20151002231825
# 24    1026034  https://www.airbnb.com/rooms/1026034  20151002231825
# 25    2486785  https://www.airbnb.com/rooms/2486785  20151002231825
# 26    1822257  https://www.airbnb.com/rooms/1822257  20151002231825
# 27    5220279  https://www.airbnb.com/rooms/5220279  20151002231825
# 28    3419118  https://www.airbnb.com/rooms/3419118  20151002231825
# 29     805961   https://www.airbnb.com/rooms/805961  20151002231825
# 30       3362     https://www.airbnb.com/rooms/3362  20151002231825
# ...
